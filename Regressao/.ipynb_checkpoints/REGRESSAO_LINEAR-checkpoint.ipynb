# %% [markdown]
# ## Regressão Linear

# %%
import numpy as np 
from numpy.random import randn 
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %% [markdown]
# ### DADOS

# %%
df = pd.DataFrame(load_boston().data, columns = load_boston().feature_names)
df['MEDV'] = load_boston().target
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### 1 - Regressão linear simples

# %% [markdown]
# $$
# y_i = \beta_0 + \beta_1 x_i + \epsilon_i,
# $$

# %% [markdown]
# #### 1.1 - Regressão linear simples - método dos mínimos quadrados

# %%
def reg_lin_simples(x,y):
    x, y = np.array(x), np.array(y)
    x_mean, y_mean = np.mean(x), np.mean(y)
    beta_1 = np.dot(x - x_mean, y - y_mean)/np.linalg.norm(x - x_mean)**2 
    beta_0 = y_mean - beta_1*x_mean
    return [beta_0, beta_1]

# %%
# Variável preditora 
x = df.AGE.values

# Variável alvo.
y = df.MEDV.values 

# Obtendo coeficientes 
beta_0, beta_1 = reg_lin_simples(x, y)

print("beta_0 =", beta_0)
print("beta_1 =", beta_1)

y_pred_mmq = x*beta_1 + beta_0
# Out:
# beta_0 = 30.97867776261804
# beta_1 = -0.12316272123567969

# %%
# Graficamente 

plt.figure(figsize = (15, 5))

plt.scatter(x, y)
plt.plot(x, y_pred_mmq, color = 'red', label = 'Linha de regressão')

plt.xlabel("x", fontsize = 15)
plt.ylabel("y", fontsize = 15)

plt.legend(fontsize = 15)

plt.show()

# %% [markdown]
# #### 1.2 - Regressão linear simples - usando framework sklearn

# %%
# X deve sempre ser uma matriz ao usar o scikit-learn
X = df.AGE.values.reshape((len(df.AGE), 1)) 
y = df.MEDV 
print(X.shape) 

# Criando e treinando um modelo
modelo = LinearRegression().fit(X, y)
print("beta_0 = ", modelo.intercept_) 
print("beta_1 = ", modelo.coef_[0]) 

y_pred_skl = modelo.predict(X)
# Out:
# (506, 1)
# beta_0 =  30.97867776261804
# beta_1 =  -0.1231627212356797

# %% [markdown]
# ### 2 - Regressão linear múltipla

# %% [markdown]
# $$
# Y = \beta_0 + \beta_1 x_1 + ... + \beta_p x_p+ \epsilon
# $$
#
# $$ \beta_{}^{*} = (X^tX)^-1X^tY $$

# %%
# Variáveis preditoras 
X = df.iloc[:,:-1]
X = sm.add_constant(X).values 

# Variável alvo
y = df.MEDV.values 

# Obtendo os coeficientes usando a equação normal 
B = np.dot(np.linalg.pinv(np.dot(X.T, X)), np.dot(X.T,y))

# Imprimindo os coeficientes 
for i in range(len(B)):
    print("beta_%s = %f" %(i, B[i]))
    
y_pred_mmq = np.dot(X, B)
# Out:
# beta_0 = 36.459488
# beta_1 = -0.108011
# beta_2 = 0.046420
# beta_3 = 0.020559
# beta_4 = 2.686734
# beta_5 = -17.766611
# beta_6 = 3.809865
# beta_7 = 0.000692
# beta_8 = -1.475567
# beta_9 = 0.306049
# beta_10 = -0.012335
# beta_11 = -0.952747
# beta_12 = 0.009312
# beta_13 = -0.524758

# %%
X = df.iloc[:,:-1]
y = df.MEDV.values 

# Criando e treinando um modelo
modelo = LinearRegression().fit(X, y)

# Imprimindo os coeficientes 
print("beta_0 =", modelo.intercept_)
for i in range(len(modelo.coef_)):
    print("beta_%s = %f" %(i + 1, modelo.coef_[i]))
    
y_pred_skl = modelo.predict(X)
# Out:
# beta_0 = 36.459488385089855
# beta_1 = -0.108011
# beta_2 = 0.046420
# beta_3 = 0.020559
# beta_4 = 2.686734
# beta_5 = -17.766611
# beta_6 = 3.809865
# beta_7 = 0.000692
# beta_8 = -1.475567
# beta_9 = 0.306049
# beta_10 = -0.012335
# beta_11 = -0.952747
# beta_12 = 0.009312
# beta_13 = -0.524758

# %% [markdown]
# ### 3 - Regressão linear - método do gradiente descendente.

# %%
# Em construção
